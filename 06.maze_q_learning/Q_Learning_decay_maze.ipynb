# %% [markdown]
# # Q-Learning
# - 탐험(Exploration)을 하면서도 최적의 정책을 학습이 가능함(상대적으로 SARSA에 비해서)
# - Off-Policy
#     - SARSA와 같은 on-policy는 이전 정책으로부터 얻은 샘플을 재사용할 수 없고, 자신의 샘플로 자신을 업데이트하므로 문제점이 존재할 수 있음
#     - 정책이 복수개이므로 behavior policy(현재의 예시에선 입실론 그리디)로 샘플을 수집하고 target policy로 최적의 정책을 학습
# - 학습하는 정책(TD) : 탐욕정책 -> exploitation
#
# $$q(s, a) = q(s, a) + \alpha \big( r + \gamma\ max_{a'} q(s', a') - q(s, a)  \big )$$
#
# - 행동하는 정책 : $\epsilon$-greedy -> exploration
#     - 종류 : $\epsilon$-greedy, BoltzMann, Bayesian, ...
#     - 아래의 예는 SARSA와 같은 입실론 그리디
#
# $$\pi(s) = \begin{cases}
#     a^* = argmax_{a \in A} q(s, a), 1 - \epsilon \\
#     \text{random action}, \ \epsilon
# \end{cases}$$

# %%
import matplotlib
matplotlib.use("Agg")
from matplotlib import pyplot as plt
from matplotlib.pyplot import ylim
import os
import numpy as np
import random
from collections import defaultdict
import gym
import gym_maze
np.random.seed(1)

# %%
plt.style.use('ggplot')
ylim((-2, 1))
env = gym.make('maze-sample-10x10-v0')

# State 의 boundary
STATE_BOUNDS = list(zip(env.observation_space.low, env.observation_space.high))
# Maze의 size (10, 10)
NUM_GRID = tuple((env.observation_space.high + np.ones(env.observation_space.shape)).astype(int))
# action space
ACTION = ['up', 'dw', 'ri', 'le']

# gui환경의 Render 여부
RENDER = False

class QLearningAgent:
    def __init__(self, actions):
        self.actions = actions
        self.learning_rate = 0.9
        self.discount_factor = 0.9
        self.epsilon = 1.0
        self.e_step = (1.0 - 0.01) / 100 # 100번의 에피소드에 결처서 입실론 디케이 설정
        self.lr_step = (0.9 - 0.2) / 100 # 100번의 에피소드에 컬쳐서 lr디케이 설정
        self.q_table = defaultdict(lambda : [0.0, 0.0, 0.0, 0.0])

    # <s, a, r, s'>로 큐함수를 업데이트
    def learn(self, state, action, reward, next_state):
        q_1 = self.q_table[state][action]
        # 벨만 최적 방정식
        q_2 = reward + self.discount_factor * max(self.q_table[next_state])
        self.q_table[state][action] += self.learning_rate * (q_2 - q_1)
    
    # 큐함수에 근거해서 엡실론 그리디하게 샘플을 획득
    def get_action(self, state):
        if np.random.rand() < self.epsilon:
            # 무작위 행동 선택
            action = np.random.choice(self.actions)
        else:
            # 큐함수에 따른 행동 반환
            state_action = self.q_table[state]
            action = self.arg_max(state_action)
        return int(action)
    
    @staticmethod
    def arg_max(state_action):
        max_index_list = []
        max_value = state_action[0]
        for index, value in enumerate(state_action):
            if value > max_value:
                max_index_list.clear()
                max_value = value
                max_index_list.append(index)
            elif value == max_value:
                max_index_list.append(index)
        return random.choice(max_index_list)
    
    # greedy 정책 출력
    def print_policy(self):
        for y in range(NUM_GRID[0]):
            for x in range(NUM_GRID[1]):
                print("% s"%ACTION[self.arg_max(self.q_table[str((x, y))])], end=" ")
            print("")
            
def state_to_bucket(state):
    bucket_indice = []
    for i in range(len(state)):
        if state[i] <= STATE_BOUNDS[i][0]:
            bucket_index = 0
        elif state[i] >= STATE_BOUNDS[i][1]:
            bucket_index = NUM_GRID[i] - 1
        else:
            # Mapping the state bounds to the bucket array
            bound_width = STATE_BOUNDS[i][1] - STATE_BOUNDS[i][0]
            offset = (NUM_GRID[i] - 1) * STATE_BOUNDS[i][0] / bound_width
            scaling = (NUM_GRID[i] - 1) / bound_width
            bucket_index = int(round(scaling * state[i] - offset))
        bucket_indice.append(bucket_index)
    return tuple(bucket_indice)

if __name__ == "__main__":
    env.reset()
    agent = QLearningAgent(actions=list(range(env.action_space.n)))
    scores = []
    episodes = []
    
    for episode in range(250):
        state = env.reset()
        state = state_to_bucket(state)
        total_reward = 0
        
        while True:
            if RENDER:
                env.render()
            
            # 1. 스텝마다 exploration을 수행함
            # 2. 스텝마다 학습을 수행함
            
            # 현재 상태에 대한 행동을 선택
            action = agent.get_action(str(state))
            
            next_state, reward, done, _ = env.step(action)
            next_state = state_to_bucket(next_state)
            
            # <s, a, r, s'>
            agent.learn(str(state), action, reward, str(next_state))
            total_reward += reward
            state = next_state
            
            # 에피소드마다 epsilone과 lr를 decay설정
            if done:
                print("Episodes : %d, Total reward : %f ."%(episode, total_reward))
                print(agent.learning_rate, agent.epsilon)
                agent.epsilon -= agent.e_step
                agent.learning_rate -= agent.lr_step
                episodes.append(episode)
                scores.append(total_reward)
                
                if agent.learning_rate < 0.2:
                    agent.learning_rate = 0.2
                
                if agent.epsilon < 0.01:
                    agent.epsilon = 0.01
                    
                if episode % 50 == 0:
                    if not os.path.isdir('./save_graph'):
                        os.mkdir('./save_graph')
                    plt.plot(episodes, scores)
                    plt.savefig('./save_graph/q_learning_both_decay.png')
                break
                
        if np.mean(scores[-min(10, len(scores)):]) > 0.93:
            RENDER = True
            agent.print_policy()
        else:
            RENDER = False
    env.close()
# Out:
# [2018-05-07 16:59:11,226] Making new env: maze-sample-10x10-v0
# Episodes : 0, Total reward : -4.801000 .
# 0.9 1.0
# Episodes : 1, Total reward : -3.961000 .
# 0.893 0.9901
# Episodes : 2, Total reward : -4.462000 .
# 0.886 0.9802
# Episodes : 3, Total reward : -3.812000 .
# 0.879 0.9702999999999999
# Episodes : 4, Total reward : -0.062000 .
# 0.872 0.9603999999999999
# Episodes : 5, Total reward : -3.665000 .
# 0.865 0.9504999999999999
# Episodes : 6, Total reward : -0.894000 .
# 0.858 0.9405999999999999
# Episodes : 7, Total reward : -1.933000 .
# 0.851 0.9306999999999999
# Episodes : 8, Total reward : -0.608000 .
# 0.844 0.9207999999999998
# Episodes : 9, Total reward : 0.019000 .
# 0.837 0.9108999999999998
# Episodes : 10, Total reward : 0.158000 .
# 0.83 0.9009999999999998
# Episodes : 11, Total reward : 0.141000 .
# 0.823 0.8910999999999998
# Episodes : 12, Total reward : 0.025000 .
# 0.816 0.8811999999999998
# Episodes : 13, Total reward : 0.637000 .
# 0.8089999999999999 0.8712999999999997
# Episodes : 14, Total reward : 0.444000 .
# 0.8019999999999999 0.8613999999999997
# Episodes : 15, Total reward : 0.485000 .
# 0.7949999999999999 0.8514999999999997
# Episodes : 16, Total reward : 0.449000 .
# 0.7879999999999999 0.8415999999999997
# Episodes : 17, Total reward : 0.689000 .
# 0.7809999999999999 0.8316999999999997
# Episodes : 18, Total reward : 0.696000 .
# 0.7739999999999999 0.8217999999999996
# Episodes : 19, Total reward : 0.342000 .
# 0.7669999999999999 0.8118999999999996
# Episodes : 20, Total reward : 0.545000 .
# 0.7599999999999999 0.8019999999999996
# Episodes : 21, Total reward : 0.716000 .
# 0.7529999999999999 0.7920999999999996
# Episodes : 22, Total reward : 0.609000 .
# 0.7459999999999999 0.7821999999999996
# Episodes : 23, Total reward : 0.502000 .
# 0.7389999999999999 0.7722999999999995
# Episodes : 24, Total reward : 0.572000 .
# 0.7319999999999999 0.7623999999999995
# Episodes : 25, Total reward : 0.719000 .
# 0.7249999999999999 0.7524999999999995
# Episodes : 26, Total reward : 0.641000 .
# 0.7179999999999999 0.7425999999999995
# Episodes : 27, Total reward : 0.725000 .
# 0.7109999999999999 0.7326999999999995
# Episodes : 28, Total reward : 0.766000 .
# 0.7039999999999998 0.7227999999999994
# Episodes : 29, Total reward : 0.851000 .
# 0.6969999999999998 0.7128999999999994
# Episodes : 30, Total reward : 0.812000 .
# 0.6899999999999998 0.7029999999999994
# Episodes : 31, Total reward : 0.681000 .
# 0.6829999999999998 0.6930999999999994
# Episodes : 32, Total reward : 0.839000 .
# 0.6759999999999998 0.6831999999999994
# Episodes : 33, Total reward : 0.798000 .
# 0.6689999999999998 0.6732999999999993
# Episodes : 34, Total reward : 0.751000 .
# 0.6619999999999998 0.6633999999999993
# Episodes : 35, Total reward : 0.843000 .
# 0.6549999999999998 0.6534999999999993
# Episodes : 36, Total reward : 0.806000 .
# 0.6479999999999998 0.6435999999999993
# Episodes : 37, Total reward : 0.809000 .
# 0.6409999999999998 0.6336999999999993
# Episodes : 38, Total reward : 0.861000 .
# 0.6339999999999998 0.6237999999999992
# Episodes : 39, Total reward : 0.834000 .
# 0.6269999999999998 0.6138999999999992
# Episodes : 40, Total reward : 0.823000 .
# 0.6199999999999998 0.6039999999999992
# Episodes : 41, Total reward : 0.855000 .
# 0.6129999999999998 0.5940999999999992
# Episodes : 42, Total reward : 0.857000 .
# 0.6059999999999998 0.5841999999999992
# Episodes : 43, Total reward : 0.775000 .
# 0.5989999999999998 0.5742999999999991
# Episodes : 44, Total reward : 0.874000 .
# 0.5919999999999997 0.5643999999999991
# Episodes : 45, Total reward : 0.879000 .
# 0.5849999999999997 0.5544999999999991
# Episodes : 46, Total reward : 0.852000 .
# 0.5779999999999997 0.5445999999999991
# Episodes : 47, Total reward : 0.875000 .
# 0.5709999999999997 0.5346999999999991
# Episodes : 48, Total reward : 0.886000 .
# 0.5639999999999997 0.524799999999999
# Episodes : 49, Total reward : 0.892000 .
# 0.5569999999999997 0.514899999999999
# Episodes : 50, Total reward : 0.879000 .
# 0.5499999999999997 0.504999999999999
# Episodes : 51, Total reward : 0.881000 .
# 0.5429999999999997 0.495099999999999
# Episodes : 52, Total reward : 0.869000 .
# 0.5359999999999997 0.48519999999999897
# Episodes : 53, Total reward : 0.884000 .
# 0.5289999999999997 0.47529999999999895
# Episodes : 54, Total reward : 0.897000 .
# 0.5219999999999997 0.4653999999999989
# Episodes : 55, Total reward : 0.894000 .
# 0.5149999999999997 0.4554999999999989
# Episodes : 56, Total reward : 0.893000 .
# 0.5079999999999997 0.4455999999999989
# Episodes : 57, Total reward : 0.870000 .
# 0.5009999999999997 0.43569999999999887
# Episodes : 58, Total reward : 0.909000 .
# 0.49399999999999966 0.42579999999999885
# Episodes : 59, Total reward : 0.900000 .
# 0.48699999999999966 0.4158999999999988
# Episodes : 60, Total reward : 0.903000 .
# 0.47999999999999965 0.4059999999999988
# Episodes : 61, Total reward : 0.913000 .
# 0.47299999999999964 0.3960999999999988
# Episodes : 62, Total reward : 0.886000 .
# 0.46599999999999964 0.38619999999999877
# Episodes : 63, Total reward : 0.900000 .
# 0.45899999999999963 0.37629999999999875
# Episodes : 64, Total reward : 0.899000 .
# 0.4519999999999996 0.3663999999999987
# Episodes : 65, Total reward : 0.883000 .
# 0.4449999999999996 0.3564999999999987
# Episodes : 66, Total reward : 0.910000 .
# 0.4379999999999996 0.3465999999999987
# Episodes : 67, Total reward : 0.897000 .
# 0.4309999999999996 0.33669999999999867
# Episodes : 68, Total reward : 0.913000 .
# 0.4239999999999996 0.32679999999999865
# Episodes : 69, Total reward : 0.912000 .
# 0.4169999999999996 0.3168999999999986
# Episodes : 70, Total reward : 0.917000 .
# 0.4099999999999996 0.3069999999999986
# Episodes : 71, Total reward : 0.907000 .
# 0.4029999999999996 0.2970999999999986
# Episodes : 72, Total reward : 0.919000 .
# 0.3959999999999996 0.28719999999999857
# Episodes : 73, Total reward : 0.916000 .
# 0.38899999999999957 0.27729999999999855
# Episodes : 74, Total reward : 0.917000 .
# 0.38199999999999956 0.2673999999999985
# Episodes : 75, Total reward : 0.914000 .
# 0.37499999999999956 0.2574999999999985
# Episodes : 76, Total reward : 0.920000 .
# 0.36799999999999955 0.24759999999999852
# Episodes : 77, Total reward : 0.914000 .
# 0.36099999999999954 0.23769999999999852
# Episodes : 78, Total reward : 0.916000 .
# 0.35399999999999954 0.22779999999999853
# Episodes : 79, Total reward : 0.925000 .
# 0.34699999999999953 0.21789999999999854
# Episodes : 80, Total reward : 0.922000 .
# 0.3399999999999995 0.20799999999999855
# Episodes : 81, Total reward : 0.924000 .
# 0.3329999999999995 0.19809999999999856
# Episodes : 82, Total reward : 0.923000 .
# 0.3259999999999995 0.18819999999999856
# Episodes : 83, Total reward : 0.923000 .
# 0.3189999999999995 0.17829999999999857
# Episodes : 84, Total reward : 0.918000 .
# 0.3119999999999995 0.16839999999999858
# Episodes : 85, Total reward : 0.920000 .
# 0.3049999999999995 0.1584999999999986
# Episodes : 86, Total reward : 0.930000 .
# 0.2979999999999995 0.1485999999999986
# Episodes : 87, Total reward : 0.927000 .
# 0.2909999999999995 0.1386999999999986
# Episodes : 88, Total reward : 0.928000 .
# 0.2839999999999995 0.1287999999999986
# Episodes : 89, Total reward : 0.934000 .
# 0.27699999999999947 0.11889999999999862
# Episodes : 90, Total reward : 0.931000 .
# 0.26999999999999946 0.10899999999999863
# Episodes : 91, Total reward : 0.932000 .
# 0.26299999999999946 0.09909999999999863
# Episodes : 92, Total reward : 0.932000 .
# 0.25599999999999945 0.08919999999999864
# Episodes : 93, Total reward : 0.939000 .
# 0.24899999999999944 0.07929999999999865
# Episodes : 94, Total reward : 0.933000 .
# 0.24199999999999944 0.06939999999999866
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# dw dw ri dw up le dw up dw le
# le dw dw ri ri up ri up dw dw
# up ri up ri ri ri ri ri ri up
# Episodes : 95, Total reward : 0.938000 .
# 0.23499999999999943 0.05949999999999866
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# le dw ri dw up le dw up dw le
# up dw ri ri ri up ri up dw ri
# dw ri up ri ri ri ri ri ri dw
# Episodes : 96, Total reward : 0.937000 .
# 0.22799999999999943 0.04959999999999866
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# le dw ri dw up le dw up dw le
# dw dw ri ri ri up ri up dw up
# dw ri up ri ri ri ri ri ri le
# Episodes : 97, Total reward : 0.936000 .
# 0.22099999999999942 0.03969999999999866
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# up dw ri dw up le dw up dw le
# le dw ri ri ri up ri up dw ri
# dw ri up ri ri ri ri ri ri up
# Episodes : 98, Total reward : 0.937000 .
# 0.2139999999999994 0.02979999999999866
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# up dw ri dw up le dw up dw le
# ri dw ri ri ri up ri up dw up
# up ri up ri ri ri ri ri ri up
# Episodes : 99, Total reward : 0.938000 .
# 0.2069999999999994 0.019899999999998662
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# le dw ri dw up le dw up dw le
# dw dw dw ri ri up ri up dw le
# up ri up ri ri ri ri ri ri le
# Episodes : 100, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# up dw ri dw up le dw up dw le
# dw dw ri ri ri up ri up dw le
# dw ri up ri ri ri ri ri ri le
# Episodes : 101, Total reward : 0.937000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# dw dw ri dw up le dw up dw le
# le dw ri ri ri up ri up dw dw
# dw ri up ri ri ri ri ri ri dw
# Episodes : 102, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# dw dw ri dw up le dw up dw le
# le dw ri ri ri up ri up dw up
# up ri up ri ri ri ri ri ri ri
# Episodes : 103, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# le dw ri dw up le dw up dw le
# ri dw ri ri ri up ri up dw ri
# dw ri up ri ri ri ri ri ri ri
# Episodes : 104, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# ri dw ri dw up le dw up dw le
# dw dw ri ri ri up ri up dw up
# dw ri up ri ri ri ri ri ri ri
# Episodes : 105, Total reward : 0.937000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# up dw ri dw up le dw up dw le
# ri dw ri ri ri up ri up dw up
# dw ri up ri ri ri ri ri ri dw
# Episodes : 106, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# up dw ri dw up le dw up dw le
# ri dw ri ri ri up ri up dw dw
# up ri up ri ri ri ri ri ri ri
# Episodes : 107, Total reward : 0.936000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# le dw ri dw up le dw up dw le
# dw dw ri ri ri up ri up dw ri
# dw ri up ri ri ri ri ri ri dw
# Episodes : 108, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# dw dw ri dw up le dw up dw le
# up dw ri ri ri up ri up dw dw
# dw ri up ri ri ri ri ri ri dw
# Episodes : 109, Total reward : 0.937000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# le dw ri dw up le dw up dw le
# le dw ri ri ri up ri up dw up
# dw ri up ri ri ri ri ri ri up
# Episodes : 110, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# le dw ri dw up le dw up dw le
# dw dw dw ri ri up ri up dw le
# dw ri up ri ri ri ri ri ri up
# Episodes : 111, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# up dw ri dw up le dw up dw le
# ri dw ri ri ri up ri up dw up
# up ri up ri ri ri ri ri ri le
# Episodes : 112, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# up dw ri dw up le dw up dw le
# ri dw dw ri ri up ri up dw ri
# dw ri up ri ri ri ri ri ri dw
# Episodes : 113, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# up dw ri dw up le dw up dw le
# dw dw dw ri ri up ri up dw dw
# dw ri up ri ri ri ri ri ri le
# Episodes : 114, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# up dw ri dw up le dw up dw le
# up dw dw ri ri up ri up dw up
# dw ri up ri ri ri ri ri ri dw
# Episodes : 115, Total reward : 0.938000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# dw dw ri dw up le dw up dw le
# ri dw dw ri ri up ri up dw dw
# up ri up ri ri ri ri ri ri ri
# Episodes : 116, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# up dw ri dw up le dw up dw le
# up dw ri ri ri up ri up dw le
# dw ri up ri ri ri ri ri ri dw
# Episodes : 117, Total reward : 0.936000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# le dw ri dw up le dw up dw le
# up dw dw ri ri up ri up dw le
# up ri up ri ri ri ri ri ri ri
# Episodes : 118, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# ri dw ri dw up le dw up dw le
# dw dw ri ri ri up ri up dw ri
# dw ri up ri ri ri ri ri ri dw
# Episodes : 119, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# dw dw ri dw up le dw up dw le
# le dw dw ri ri up ri up dw dw
# up ri up ri ri ri ri ri ri le
# Episodes : 120, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# le dw ri dw up le dw up dw le
# ri dw ri ri ri up ri up dw up
# dw ri up ri ri ri ri ri ri dw
# Episodes : 121, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# le dw ri dw up le dw up dw le
# dw dw dw ri ri up ri up dw le
# up ri up ri ri ri ri ri ri dw
# Episodes : 122, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# le dw ri dw up le dw up dw le
# ri dw dw ri ri up ri up dw up
# dw ri up ri ri ri ri ri ri dw
# Episodes : 123, Total reward : 0.938000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# dw dw ri dw up le dw up dw le
# up dw dw ri ri up ri up dw ri
# dw ri up ri ri ri ri ri ri le
# Episodes : 124, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# ri dw ri dw up le dw up dw le
# up dw ri ri ri up ri up dw ri
# dw ri up ri ri ri ri ri ri ri
# Episodes : 125, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# le dw ri dw up le dw up dw le
# le dw ri ri ri up ri up dw le
# up ri up ri ri ri ri ri ri le
# Episodes : 126, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# ri dw ri dw up le dw up dw le
# ri dw dw ri ri up ri up dw dw
# up ri up ri ri ri ri ri ri up
# Episodes : 127, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# ri dw ri dw up le dw up dw le
# le dw dw ri ri up ri up dw up
# up ri up ri ri ri ri ri ri dw
# Episodes : 128, Total reward : 0.937000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# up dw ri dw up le dw up dw le
# ri dw ri ri ri up ri up dw le
# up ri up ri ri ri ri ri ri dw
# Episodes : 129, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# ri dw ri dw up le dw up dw le
# dw dw ri ri ri up ri up dw up
# up ri up ri ri ri ri ri ri up
# Episodes : 130, Total reward : 0.938000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# dw dw ri dw up le dw up dw le
# dw dw ri ri ri up ri up dw le
# dw ri up ri ri ri ri ri ri ri
# Episodes : 131, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# dw dw ri dw up le dw up dw le
# dw dw dw ri ri up ri up dw ri
# up ri up ri ri ri ri ri ri dw
# Episodes : 132, Total reward : 0.936000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# ri dw ri dw up le dw up dw le
# le dw ri ri ri up ri up dw dw
# up ri up ri ri ri ri ri ri dw
# Episodes : 133, Total reward : 0.937000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# ri dw ri dw up le dw up dw le
# le dw dw ri ri up ri up dw ri
# dw ri up ri ri ri ri ri ri up
# Episodes : 134, Total reward : 0.937000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# dw dw ri dw up le dw up dw le
# dw dw ri ri ri up ri up dw dw
# dw ri up ri ri ri ri ri ri dw
# Episodes : 135, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# ri dw ri dw up le dw up dw le
# ri dw ri ri ri up ri up dw dw
# up ri up ri ri ri ri ri ri le
# Episodes : 136, Total reward : 0.936000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# ri dw ri dw up le dw up dw le
# ri dw ri ri ri up ri up dw dw
# up ri up ri ri ri ri ri ri ri
# Episodes : 137, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# le dw ri dw up le dw up dw le
# ri dw ri ri ri up ri up dw dw
# dw ri up ri ri ri ri ri ri ri
# Episodes : 138, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# ri dw ri dw up le dw up dw le
# up dw ri ri ri up ri up dw ri
# dw ri up ri ri ri ri ri ri le
# Episodes : 139, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# up dw ri dw up le dw up dw le
# le dw ri ri ri up ri up dw dw
# up ri up ri ri ri ri ri ri up
# Episodes : 140, Total reward : 0.938000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# le dw ri dw up le dw up dw le
# le dw ri ri ri up ri up dw ri
# dw ri up ri ri ri ri ri ri up
# Episodes : 141, Total reward : 0.936000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# up dw ri dw up le dw up dw le
# up dw ri ri ri up ri up dw up
# dw ri up ri ri ri ri ri ri le
# Episodes : 142, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# ri dw ri dw up le dw up dw le
# dw dw dw ri ri up ri up dw dw
# dw ri up ri ri ri ri ri ri le
# Episodes : 143, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# dw dw ri dw up le dw up dw le
# le dw ri ri ri up ri up dw ri
# dw ri up ri ri ri ri ri ri ri
# Episodes : 144, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# dw dw ri dw up le dw up dw le
# ri dw dw ri ri up ri up dw ri
# dw ri up ri ri ri ri ri ri up
# Episodes : 145, Total reward : 0.937000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# le dw ri dw up le dw up dw le
# ri dw ri ri ri up ri up dw up
# dw ri up ri ri ri ri ri ri up
# Episodes : 146, Total reward : 0.938000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# dw dw ri dw up le dw up dw le
# ri dw dw ri ri up ri up dw up
# dw ri up ri ri ri ri ri ri up
# Episodes : 147, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# ri dw ri dw up le dw up dw le
# up dw dw ri ri up ri up dw dw
# up ri up ri ri ri ri ri ri dw
# Episodes : 148, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# le dw ri dw up le dw up dw le
# up dw dw ri ri up ri up dw up
# up ri up ri ri ri ri ri ri le
# Episodes : 149, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# le dw ri dw up le dw up dw le
# up dw ri ri ri up ri up dw ri
# up ri up ri ri ri ri ri ri dw
# Episodes : 150, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# ri dw ri dw up le dw up dw le
# le dw ri ri ri up ri up dw dw
# up ri up ri ri ri ri ri ri dw
# Episodes : 151, Total reward : 0.937000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# le dw ri dw up le dw up dw le
# le dw ri ri ri up ri up dw up
# up ri up ri ri ri ri ri ri le
# Episodes : 152, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# ri dw ri dw up le dw up dw le
# up dw ri ri ri up ri up dw le
# up ri up ri ri ri ri ri ri ri
# Episodes : 153, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# ri dw ri dw up le dw up dw le
# dw dw dw ri ri up ri up dw ri
# up ri up ri ri ri ri ri ri dw
# Episodes : 154, Total reward : 0.938000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# le dw ri dw up le dw up dw le
# le dw ri ri ri up ri up dw le
# up ri up ri ri ri ri ri ri ri
# Episodes : 155, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# up dw ri dw up le dw up dw le
# le dw dw ri ri up ri up dw le
# dw ri up ri ri ri ri ri ri up
# Episodes : 156, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# dw dw ri dw up le dw up dw le
# ri dw ri ri ri up ri up dw ri
# up ri up ri ri ri ri ri ri ri
# Episodes : 157, Total reward : 0.937000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# ri dw ri dw up le dw up dw le
# ri dw ri ri ri up ri up dw dw
# dw ri up ri ri ri ri ri ri dw
# Episodes : 158, Total reward : 0.938000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# up dw ri dw up le dw up dw le
# up dw ri ri ri up ri up dw up
# up ri up ri ri ri ri ri ri up
# Episodes : 159, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# le dw ri dw up le dw up dw le
# le dw dw ri ri up ri up dw le
# up ri up ri ri ri ri ri ri up
# Episodes : 160, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# dw dw ri dw up le dw up dw le
# dw dw dw ri ri up ri up dw le
# dw ri up ri ri ri ri ri ri ri
# Episodes : 161, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# le dw ri dw up le dw up dw le
# le dw ri ri ri up ri up dw ri
# dw ri up ri ri ri ri ri ri dw
# Episodes : 162, Total reward : 0.937000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# up dw ri dw up le dw up dw le
# le dw ri ri ri up ri up dw up
# up ri up ri ri ri ri ri ri ri
# Episodes : 163, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# le dw ri dw up le dw up dw le
# up dw dw ri ri up ri up dw dw
# up ri up ri ri ri ri ri ri dw
# Episodes : 164, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# le dw ri dw up le dw up dw le
# dw dw dw ri ri up ri up dw le
# dw ri up ri ri ri ri ri ri le
# Episodes : 165, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# dw dw ri dw up le dw up dw le
# up dw dw ri ri up ri up dw dw
# dw ri up ri ri ri ri ri ri le
# Episodes : 166, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# dw dw ri dw up le dw up dw le
# le dw dw ri ri up ri up dw le
# dw ri up ri ri ri ri ri ri up
# Episodes : 167, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# le dw ri dw up le dw up dw le
# up dw dw ri ri up ri up dw le
# up ri up ri ri ri ri ri ri le
# Episodes : 168, Total reward : 0.938000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# le dw ri dw up le dw up dw le
# dw dw ri ri ri up ri up dw dw
# up ri up ri ri ri ri ri ri up
# Episodes : 169, Total reward : 0.938000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# le dw ri dw up le dw up dw le
# le dw ri ri ri up ri up dw le
# dw ri up ri ri ri ri ri ri ri
# Episodes : 170, Total reward : 0.938000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# dw dw ri dw up le dw up dw le
# dw dw dw ri ri up ri up dw dw
# dw ri up ri ri ri ri ri ri le
# Episodes : 171, Total reward : 0.937000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# up dw ri dw up le dw up dw le
# le dw dw ri ri up ri up dw ri
# dw ri up ri ri ri ri ri ri le
# Episodes : 172, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# dw dw ri dw up le dw up dw le
# le dw dw ri ri up ri up dw le
# dw ri up ri ri ri ri ri ri le
# Episodes : 173, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# up dw ri dw up le dw up dw le
# ri dw ri ri ri up ri up dw dw
# dw ri up ri ri ri ri ri ri ri
# Episodes : 174, Total reward : 0.938000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# ri dw ri dw up le dw up dw le
# up dw ri ri ri up ri up dw ri
# dw ri up ri ri ri ri ri ri ri
# Episodes : 175, Total reward : 0.937000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# dw dw ri dw up le dw up dw le
# ri dw dw ri ri up ri up dw up
# up ri up ri ri ri ri ri ri le
# Episodes : 176, Total reward : 0.938000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# ri dw ri dw up le dw up dw le
# ri dw ri ri ri up ri up dw ri
# dw ri up ri ri ri ri ri ri dw
# Episodes : 177, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# dw dw ri dw up le dw up dw le
# le dw dw ri ri up ri up dw le
# up ri up ri ri ri ri ri ri up
# Episodes : 178, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# le dw ri dw up le dw up dw le
# up dw ri ri ri up ri up dw le
# up ri up ri ri ri ri ri ri dw
# Episodes : 179, Total reward : 0.938000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# ri dw ri dw up le dw up dw le
# ri dw ri ri ri up ri up dw up
# up ri up ri ri ri ri ri ri ri
# Episodes : 180, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# ri dw ri dw up le dw up dw le
# dw dw ri ri ri up ri up dw dw
# up ri up ri ri ri ri ri ri up
# Episodes : 181, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# dw dw ri dw up le dw up dw le
# ri dw dw ri ri up ri up dw ri
# up ri up ri ri ri ri ri ri dw
# Episodes : 182, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# dw dw ri dw up le dw up dw le
# up dw ri ri ri up ri up dw up
# up ri up ri ri ri ri ri ri le
# Episodes : 183, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# dw dw ri dw up le dw up dw le
# up dw dw ri ri up ri up dw ri
# up ri up ri ri ri ri ri ri ri
# Episodes : 184, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# ri dw ri dw up le dw up dw le
# up dw dw ri ri up ri up dw dw
# dw ri up ri ri ri ri ri ri ri
# Episodes : 185, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# ri dw ri dw up le dw up dw le
# dw dw dw ri ri up ri up dw ri
# dw ri up ri ri ri ri ri ri dw
# Episodes : 186, Total reward : 0.938000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# dw dw ri dw up le dw up dw le
# up dw ri ri ri up ri up dw ri
# dw ri up ri ri ri ri ri ri ri
# Episodes : 187, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# le dw ri dw up le dw up dw le
# le dw dw ri ri up ri up dw ri
# dw ri up ri ri ri ri ri ri ri
# Episodes : 188, Total reward : 0.937000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# le dw ri dw up le dw up dw le
# le dw ri ri ri up ri up dw up
# up ri up ri ri ri ri ri ri dw
# Episodes : 189, Total reward : 0.938000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# le dw ri dw up le dw up dw le
# ri dw dw ri ri up ri up dw dw
# up ri up ri ri ri ri ri ri up
# Episodes : 190, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# dw dw ri dw up le dw up dw le
# up dw dw ri ri up ri up dw le
# dw ri up ri ri ri ri ri ri le
# Episodes : 191, Total reward : 0.938000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# dw dw ri dw up le dw up dw le
# le dw dw ri ri up ri up dw le
# up ri up ri ri ri ri ri ri le
# Episodes : 192, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# ri dw ri dw up le dw up dw le
# dw dw dw ri ri up ri up dw dw
# up ri up ri ri ri ri ri ri up
# Episodes : 193, Total reward : 0.938000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# dw dw ri dw up le dw up dw le
# up dw dw ri ri up ri up dw le
# up ri up ri ri ri ri ri ri le
# Episodes : 194, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# le dw ri dw up le dw up dw le
# dw dw dw ri ri up ri up dw up
# up ri up ri ri ri ri ri ri le
# Episodes : 195, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# le dw ri dw up le dw up dw le
# le dw ri ri ri up ri up dw dw
# up ri up ri ri ri ri ri ri le
# Episodes : 196, Total reward : 0.937000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# ri dw ri dw up le dw up dw le
# le dw ri ri ri up ri up dw dw
# dw ri up ri ri ri ri ri ri up
# Episodes : 197, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# le dw ri dw up le dw up dw le
# up dw ri ri ri up ri up dw up
# up ri up ri ri ri ri ri ri ri
# Episodes : 198, Total reward : 0.936000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# up dw ri dw up le dw up dw le
# ri dw ri ri ri up ri up dw dw
# dw ri up ri ri ri ri ri ri up
# Episodes : 199, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# le dw ri dw up le dw up dw le
# up dw dw ri ri up ri up dw ri
# dw ri up ri ri ri ri ri ri dw
# Episodes : 200, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# dw dw ri dw up le dw up dw le
# dw dw dw ri ri up ri up dw ri
# up ri up ri ri ri ri ri ri ri
# Episodes : 201, Total reward : 0.937000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# up dw ri dw up le dw up dw le
# up dw dw ri ri up ri up dw up
# dw ri up ri ri ri ri ri ri ri
# Episodes : 202, Total reward : 0.938000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# dw dw ri dw up le dw up dw le
# dw dw ri ri ri up ri up dw up
# dw ri up ri ri ri ri ri ri dw
# Episodes : 203, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# le dw ri dw up le dw up dw le
# dw dw ri ri ri up ri up dw dw
# up ri up ri ri ri ri ri ri ri
# Episodes : 204, Total reward : 0.938000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# le dw ri dw up le dw up dw le
# up dw ri ri ri up ri up dw up
# up ri up ri ri ri ri ri ri le
# Episodes : 205, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# le dw ri dw up le dw up dw le
# le dw dw ri ri up ri up dw le
# up ri up ri ri ri ri ri ri up
# Episodes : 206, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# dw dw ri dw up le dw up dw le
# dw dw dw ri ri up ri up dw ri
# up ri up ri ri ri ri ri ri dw
# Episodes : 207, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# le dw ri dw up le dw up dw le
# dw dw dw ri ri up ri up dw dw
# dw ri up ri ri ri ri ri ri ri
# Episodes : 208, Total reward : 0.937000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# le dw ri dw up le dw up dw le
# up dw ri ri ri up ri up dw le
# up ri up ri ri ri ri ri ri dw
# Episodes : 209, Total reward : 0.937000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# le dw ri dw up le dw up dw le
# ri dw dw ri ri up ri up dw ri
# up ri up ri ri ri ri ri ri dw
# Episodes : 210, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# dw dw ri dw up le dw up dw le
# up dw ri ri ri up ri up dw ri
# dw ri up ri ri ri ri ri ri dw
# Episodes : 211, Total reward : 0.938000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# ri dw ri dw up le dw up dw le
# dw dw dw ri ri up ri up dw dw
# dw ri up ri ri ri ri ri ri dw
# Episodes : 212, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# le dw ri dw up le dw up dw le
# ri dw ri ri ri up ri up dw ri
# dw ri up ri ri ri ri ri ri up
# Episodes : 213, Total reward : 0.937000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# ri dw ri dw up le dw up dw le
# ri dw dw ri ri up ri up dw ri
# up ri up ri ri ri ri ri ri dw
# Episodes : 214, Total reward : 0.938000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# ri dw ri dw up le dw up dw le
# le dw dw ri ri up ri up dw dw
# up ri up ri ri ri ri ri ri le
# Episodes : 215, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# le dw ri dw up le dw up dw le
# dw dw dw ri ri up ri up dw up
# up ri up ri ri ri ri ri ri up
# Episodes : 216, Total reward : 0.938000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# dw dw ri dw up le dw up dw le
# ri dw ri ri ri up ri up dw le
# dw ri up ri ri ri ri ri ri up
# Episodes : 217, Total reward : 0.938000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# ri dw ri dw up le dw up dw le
# ri dw ri ri ri up ri up dw ri
# dw ri up ri ri ri ri ri ri dw
# Episodes : 218, Total reward : 0.937000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# dw dw ri dw up le dw up dw le
# ri dw dw ri ri up ri up dw up
# up ri up ri ri ri ri ri ri le
# Episodes : 219, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# le dw ri dw up le dw up dw le
# le dw ri ri ri up ri up dw le
# dw ri up ri ri ri ri ri ri dw
# Episodes : 220, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# le dw ri dw up le dw up dw le
# ri dw ri ri ri up ri up dw ri
# up ri up ri ri ri ri ri ri le
# Episodes : 221, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# ri dw ri dw up le dw up dw le
# le dw dw ri ri up ri up dw le
# up ri up ri ri ri ri ri ri up
# Episodes : 222, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# ri dw ri dw up le dw up dw le
# dw dw dw ri ri up ri up dw dw
# up ri up ri ri ri ri ri ri up
# Episodes : 223, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# dw dw ri dw up le dw up dw le
# up dw dw ri ri up ri up dw ri
# dw ri up ri ri ri ri ri ri le
# Episodes : 224, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# dw dw ri dw up le dw up dw le
# dw dw dw ri ri up ri up dw up
# up ri up ri ri ri ri ri ri dw
# Episodes : 225, Total reward : 0.938000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# le dw ri dw up le dw up dw le
# ri dw ri ri ri up ri up dw up
# dw ri up ri ri ri ri ri ri ri
# Episodes : 226, Total reward : 0.937000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# dw dw ri dw up le dw up dw le
# ri dw ri ri ri up ri up dw up
# dw ri up ri ri ri ri ri ri dw
# Episodes : 227, Total reward : 0.936000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# le dw ri dw up le dw up dw le
# ri dw ri ri ri up ri up dw le
# dw ri up ri ri ri ri ri ri up
# Episodes : 228, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# ri dw ri dw up le dw up dw le
# ri dw ri ri ri up ri up dw le
# dw ri up ri ri ri ri ri ri up
# Episodes : 229, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# up dw ri dw up le dw up dw le
# up dw ri ri ri up ri up dw le
# dw ri up ri ri ri ri ri ri ri
# Episodes : 230, Total reward : 0.935000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# le dw ri dw up le dw up dw le
# dw dw ri ri ri up ri up dw le
# dw ri up ri ri ri ri ri ri le
# Episodes : 231, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# ri dw ri dw up le dw up dw le
# up dw ri ri ri up ri up dw up
# dw ri up ri ri ri ri ri ri dw
# Episodes : 232, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# ri dw ri dw up le dw up dw le
# dw dw dw ri ri up ri up dw ri
# dw ri up ri ri ri ri ri ri up
# Episodes : 233, Total reward : 0.938000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# up dw ri dw up le dw up dw le
# dw dw ri ri ri up ri up dw ri
# dw ri up ri ri ri ri ri ri dw
# Episodes : 234, Total reward : 0.938000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# ri dw ri dw up le dw up dw le
# dw dw ri ri ri up ri up dw up
# up ri up ri ri ri ri ri ri le
# Episodes : 235, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# up dw ri dw up le dw up dw le
# dw dw ri ri ri up ri up dw ri
# up ri up ri ri ri ri ri ri dw
# Episodes : 236, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# ri dw ri dw up le dw up dw le
# le dw dw ri ri up ri up dw le
# dw ri up ri ri ri ri ri ri dw
# Episodes : 237, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# up dw ri dw up le dw up dw le
# dw dw dw ri ri up ri up dw up
# dw ri up ri ri ri ri ri ri dw
# Episodes : 238, Total reward : 0.938000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# ri dw ri dw up le dw up dw le
# dw dw dw ri ri up ri up dw le
# dw ri up ri ri ri ri ri ri up
# Episodes : 239, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# up dw ri dw up le dw up dw le
# le dw dw ri ri up ri up dw up
# dw ri up ri ri ri ri ri ri le
# Episodes : 240, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# up dw ri dw up le dw up dw le
# le dw ri ri ri up ri up dw up
# dw ri up ri ri ri ri ri ri dw
# Episodes : 241, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# up dw ri dw up le dw up dw le
# le dw dw ri ri up ri up dw dw
# dw ri up ri ri ri ri ri ri ri
# Episodes : 242, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# le dw ri dw up le dw up dw le
# dw dw dw ri ri up ri up dw ri
# up ri up ri ri ri ri ri ri up
# Episodes : 243, Total reward : 0.936000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# dw dw ri dw up le dw up dw le
# up dw dw ri ri up ri up dw up
# dw ri up ri ri ri ri ri ri le
# Episodes : 244, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# le dw ri dw up le dw up dw le
# up dw dw ri ri up ri up dw ri
# up ri up ri ri ri ri ri ri ri
# Episodes : 245, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# dw dw ri dw up le dw up dw le
# dw dw ri ri ri up ri up dw ri
# dw ri up ri ri ri ri ri ri ri
# Episodes : 246, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# ri dw ri dw up le dw up dw le
# le dw dw ri ri up ri up dw dw
# dw ri up ri ri ri ri ri ri le
# Episodes : 247, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# le dw ri dw up le dw up dw le
# le dw dw ri ri up ri up dw le
# up ri up ri ri ri ri ri ri up
# Episodes : 248, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# ri dw ri dw up le dw up dw le
# up dw ri ri ri up ri up dw ri
# dw ri up ri ri ri ri ri ri dw
# Episodes : 249, Total reward : 0.939000 .
# 0.2 0.01
# ri dw le ri ri ri ri ri dw dw
# dw le le le up le le le ri dw
# dw le ri ri up ri ri up dw le
# dw ri ri ri ri up dw le ri dw
# dw up up le ri dw dw le le le
# dw up ri up le dw dw ri ri dw
# ri ri ri dw up ri dw ri ri dw
# dw dw ri dw up le dw up dw le
# dw dw dw ri ri up ri up dw up
# up ri up ri ri ri ri ri ri ri
